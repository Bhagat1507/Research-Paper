# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_classification=pd.read_csv("classification_time_accuracy.csv")

# %%
data_classification
# Out:
#    Unnamed: 0  Logical Regression  Train-Time(Log Reg)  Decision Tree  \
# 0           0            0.947368             0.025999       0.947368
# 1           1            1.000000             0.022002       0.973684
# 2           2            0.947368             0.023002       0.947368
# 3           3            0.947368             0.019001       0.947368
# 4           4            0.947368             0.021000       0.947368
#
#    Train-Time(Decision Tree)  Random Forest  Train-Time(Random Forest)  \
# 0                   0.000998       0.921053                   0.118011
# 1                   0.001000       1.000000                   0.125009
# 2                   0.001001       0.947368                   0.113007
# 3                   0.001000       0.947368                   0.116010
# 4                   0.001001       0.947368                   0.117008
#
#    Naive Bayes  Train-Time(Naive Bayes)       SVM  Train-Time(SVM)
# ...

# %%
data_time=pd.concat([data_classification['Train-Time(Log Reg)'],data_classification['Train-Time(Decision Tree)'],
                              data_classification['Train-Time(Naive Bayes)'],data_classification['Train-Time(SVM)'],
                             data_classification['Train-Time(Random Forest)']],axis=1)

# %%
data_time.plot()
# Out:
# <AxesSubplot:>

# %%
data_accuracy=pd.concat([data_classification['Logical Regression'],data_classification['Decision Tree'],
                              data_classification['Naive Bayes'],data_classification['SVM'],
                             data_classification['Random Forest']],axis=1)

# %%
data_accuracy.plot()
# Out:
# <AxesSubplot:>

# %%
data_accuracy.describe()
# Out:
#        Logical Regression  Decision Tree  Naive Bayes          SVM  \
# count         1000.000000    1000.000000  1000.000000  1000.000000
# mean             0.961605       0.946342     0.952316     0.976158
# std              0.028507       0.033194     0.031026     0.022850
# min              0.842105       0.815789     0.842105     0.868421
# 25%              0.947368       0.921053     0.921053     0.973684
# 50%              0.973684       0.947368     0.947368     0.973684
# 75%              0.973684       0.973684     0.973684     1.000000
# max              1.000000       1.000000     1.000000     1.000000
#
#        Random Forest
# count    1000.000000
# mean        0.949947
# std         0.032207
# min         0.815789
# 25%         0.921053
# 50%         0.947368
# 75%         0.973684
# max         1.000000

# %%
data_time.describe()
# Out:
#        Train-Time(Log Reg)  Train-Time(Decision Tree)  \
# count          1000.000000                1000.000000
# mean              0.023795                   0.000477
# std               0.004828                   0.000508
# min               0.014001                   0.000000
# 25%               0.021002                   0.000000
# 50%               0.023002                   0.000000
# 75%               0.026000                   0.001000
# max               0.082006                   0.002005
#
#        Train-Time(Naive Bayes)  Train-Time(SVM)  Train-Time(Random Forest)
# count              1000.000000      1000.000000                1000.000000
# mean                  0.000703         0.000557                   0.120869
# std                   0.000487         0.000505                   0.018071
# min                   0.000000         0.000000                   0.102008
# 25%                   0.000000         0.000000                   0.112008
# ...

# %%
data_reg=pd.read_csv('Regression_mse_r2_accuracy')

# %%
data_reg.columns
# Out:
# Index(['Unnamed: 0', 'Time(Log_Reg)', 'Time(Lasso_Reg)', 'Time(ELastic_Reg)',
#        'Time(Rid_Reg)', 'Accuracy(Log_Reg)', 'Accuracy(Lasso_Reg)',
#        'Accuracy(Elastic_Reg)', 'Accuracy(Rid_Reg)', 'MSE(Log_Reg)',
#        'MSE(Lasso_Reg)', 'MSE(Elastic_Reg)', 'MSE(Rid_Reg)', 'R-sq(Log_Reg)',
#        'R-sq(Lasso_Reg)', 'R-sq(Elastic_Reg)', 'R-sq(Rid_Reg)'],
#       dtype='object')

# %%
data_time=pd.concat([data_reg['Time(Rid_Reg)'],data_reg['Time(ELastic_Reg)'],
                            data_reg['Time(Lasso_Reg)'],data_reg['Time(Log_Reg)']],axis=1)

# %%
data_time.plot()
# Out:
# <AxesSubplot:>
